# %%
student=["ali", "18", "karachi", "student", "200", "300"]

# %%
 student.append([name, age, city, profession, total, avg])

# %%
n = int(input("Enter No Of Student"))
# Out:
# Enter No Of Student 4

# %%
for i in range(n):
    print(f"\nStudent {i+1} data:")
# Out:
# Student 1 data:
#
# Student 2 data:
#
# Student 3 data:
#
# Student 4 data:

# %%
print ("Student No 1")
name=input("name:")
age=int(input("age: "))
city=input("city: ")
profession=input("profession:")
height=float(input("height(real): "))
Mathematics_marks=int(input("Mathematics marks:"))
Physics_marks=int(input("Physics marks:"))
# Out:
# Student No 1
# name: Shahzaman
# age:  18
# city:  Hyderabad
# profession: Graphic Designer
# height(real):  5.5
# Mathematics marks: 91
# Physics marks: 89

# %%
print("First letter:", name[0])
print("Last letter:", name[-1])
# Out:
# First letter: S
# Last letter: n

# %%
 print("Reverse name:", name[::-1])
# Out:
# Reverse name: namazhahS

# %%
print("Uppercase:", name.upper())
print("Capitalize:", name.capitalize())
# Out:
# Uppercase: SHAHZAMAN
# Capitalize: Shahzaman

# %%
 print("First 3 letters of profession:", profession[:3])
# Out:
# First 3 letters of profession: Gra

# %%
print("Every second letter of city:", city[::2])
# Out:
# Every second letter of city: Hdrbd

# %%
print("Age + 5:", age + 5)
# Out:
# Age + 5: 23

# %%
total = Mathematics_marks + Physics_marks
avg = 200 / 2
print("Total marks:", total)
print("Average marks:", avg)
# Out:
# Total marks: 180
# Average marks: 100.0

# %%
comp = complex(age, height)
print("Complex number:", comp)
# Out:
# Complex number: (18+5.5j)

# %%
print("Add:", Mathematics_marks + Physics_marks)
print("Sub:", Mathematics_marks - Physics_marks)
print("Mul:", Mathematics_marks * Physics_marks)
print("Div:", Mathematics_marks / Physics_marks)
print("Mod:", Mathematics_marks % Physics_marks)
# Out:
# Add: 180
# Sub: 2
# Mul: 8099
# Div: 1.0224719101123596
# Mod: 2

# %%
print("Mathematics > Physics:",Mathematics_marks > Physics_marks)
print("Mathematics < Physics:", Mathematics_marks < Physics_marks)
print("Equal:", Mathematics_marks == Physics_marks)
# Out:
# Mathematics > Physics: True
# Mathematics < Physics: False
# Equal: False

# %%
name_list = list(name)
city_list = list(city)

# %%
print("Name letters:", name_list)
print("Reversed letters:", name_list[::-1])
# Out:
# Name letters: ['S', 'h', 'a', 'h', 'z', 'a', 'm', 'a', 'n']
# Reversed letters: ['n', 'a', 'm', 'a', 'z', 'h', 'a', 'h', 'S']

# %%
name_list.append('X')
name_list.pop()
print("Updated list:", name_list)
# Out:
# Updated list: ['S', 'h', 'a', 'h', 'z', 'a', 'm', 'a', 'n']

# %%
letter = input("Check letter in name: ")
print(letter in name)
# Out:
# Check letter in name:  Uzair Baloch
# False

# %%
print("\n===== Summary Table =====")
print("Name\tAge\tCity\tProfession\tTotal\tAvg")

for n in student:
    print(f"{n[1]}\t")
# Out:
# ===== Summary Table =====
# Name	Age	City	Profession	Total	Avg
# l
# 8
# a
# t
# 0
# 0
# 18
